# %%
from IPython.display import Image

# %%
Image(filename='./images/random_iris_est0.jpg')

# %%
Image(filename='./images/tree_iris.jpg')

# %%
Image(filename='./images/random_zoo_est0.jpg')

# %%
Image(filename='./images/tree_zoo.jpg')

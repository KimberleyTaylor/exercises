# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm

# %%
df = pd.read_csv("Books.csv")

# %%
df
# Out:
#      Unnamed: 0                                       Title  \
# 0             0                       To Kill a Mockingbird
# 1             1                                        1984
# 2             2                            The Great Gatsby
# 3             3       Harry Potter and the Sorcerer's Stone
# 4             4         The Hobbit, or There and Back Again
# ..          ...                                         ...
# 991         991  The Snows of Kilimanjaro and Other Stories
# 992         992                    The Street of Crocodiles
# 993         993                              Riddley Walker
# 994         994                          Play It As It Lays
# 995         995                             I'm Not Stiller
#
#                   Author  Rating Count  Review Count  Rating Value  N pag  \
# 0             Harper Lee       4629082         92962          4.28  324.0
# 1          George Orwell       3250211         72375          4.19  237.0
# 2    F. Scott Fitzgerald       3877685         68965          3.93  200.0
# 3           J.K. Rowling       7281482        115354          4.48  309.0
# 4         J.R.R. Tolkien       2973224         49547          4.28  366.0
# ..                   ...           ...           ...           ...    ...
# 991     Ernest Hemingway         33823          1453          3.87  144.0
# 992         Bruno Schulz          7034           599          4.13  160.0
# 993        Russell Hoban          7075           819          4.02  256.0
# 994          Joan Didion         29879          2278          3.88  231.0
# 995           Max Frisch          3985           187          4.06  377.0
#
#      1st Pub  series                                             Genres  \
# 0     1960.0       1              ['Classics', 'Fiction', 'Historical']
# 1     1949.0       0         ['Classics', 'Fiction', 'Science Fiction']
# 2     1925.0       0                ['Classics', 'Fiction', 'Academic']
# 3     1997.0       1              ['Fantasy', 'Fiction', 'Young Adult']
# 4     1937.0       1                 ['Fantasy', 'Classics', 'Fiction']
# ..       ...     ...                                                ...
# 991   1961.0       0           ['Fiction', 'Short Stories', 'Classics']
# 992   1933.0       0  ['Fiction', 'Short Stories', 'European Literat...
# 993   1980.0       0      ['Fiction', 'Science Fiction', 'Apocalyptic']
# 994   1970.0       0                  ['Fiction', 'Classics', 'Novels']
# 995   1954.0       0  ['Fiction', 'European Literature', 'German Lit...
#
#      Awards  minmax_norm_ratings  mean_norm_ratings  \
# 0       4.0                7.705              2.330
# 1       2.0                7.161              1.787
# 2       1.0                5.591              0.216
# 3      28.0                8.913              3.538
# 4       3.0                7.705              2.330
# ..      ...                  ...                ...
# 991     NaN                5.228             -0.146
# 992     2.0                6.799              1.424
# 993     3.0                6.134              0.760
# 994     NaN                5.289             -0.086
# 995     NaN                6.376              1.002
#
#                                                   Link
# 0    https://www.goodreads.com/book/show/2657.To_Ki...
# 1    https://www.goodreads.com/book/show/40961427-1984
# 2    https://www.goodreads.com/book/show/3.Harry_Po...
# 3    https://www.goodreads.com/book/show/4671.The_G...
# 4    https://www.goodreads.com/book/show/170448.Ani...
# ..                                                 ...
# 991  https://www.goodreads.com/book/show/244261.The...
# 992  https://www.goodreads.com/book/show/4645.The_S...
# 993  https://www.goodreads.com/book/show/428.Play_I...
# 994  https://www.goodreads.com/book/show/776573.Rid...
# 995  https://www.goodreads.com/book/show/265102.I_m...
#
# [996 rows x 14 columns]

# %%
sample_df = df.sample(n = 100)

# %%
sample_df
# Out:
#      Unnamed: 0                                              Title  \
# 656         656                                    Drums of Autumn
# 843         843                                        Martin Eden
# 497         497                       The Society of the Spectacle
# 128         128              Roots: The Saga of an American Family
# 321         321                                            Ragtime
# ..          ...                                                ...
# 23           23                    One Flew Over the Cuckoo's Nest
# 611         611                      The Prime of Miss Jean Brodie
# 417         417                            All the President's Men
# 432         432              Buddenbrooks: The Decline of a Family
# 115         115  Blood Meridian, or the Evening Redness in the ...
#
#               Author  Rating Count  Review Count  Rating Value  N pag  \
# 656   Diana Gabaldon        212678          8220          4.32  904.0
# 843      Jack London         26825          1529          4.45  480.0
# 497       Guy Debord         15769           593          4.02  160.0
# 128       Alex Haley        148505          3522          4.42  729.0
# 321    E.L. Doctorow         38408          2534          3.88  320.0
# ..               ...           ...           ...           ...    ...
# 23         Ken Kesey        641349         11366          4.19  325.0
# 611     Muriel Spark         43496          2925          3.74  150.0
# 417   Carl Bernstein         47959          1671          4.18  480.0
# 432      Thomas Mann         22307          1180          4.16  731.0
# 115  Cormac McCarthy        111249          9999          4.17  351.0
#
#      1st Pub  series                                           Genres  Awards  \
# 656   1996.0       1  ['Historical', 'Historical Fiction', 'Romance']     1.0
# 843   1909.0       0            ['Classics', 'Fiction', 'Literature']     NaN
# 497   1967.0       0         ['Philosophy', 'Nonfiction', 'Politics']     NaN
# 128   1976.0       0  ['Historical', 'Historical Fiction', 'Fiction']     5.0
# 321   1975.0       0  ['Fiction', 'Historical', 'Historical Fiction']     2.0
# ..       ...     ...                                              ...     ...
# 23    1962.0       0            ['Classics', 'Fiction', 'Literature']     NaN
# 611   1961.0       0            ['Fiction', 'Classics', 'Historical']     NaN
# 417   1974.0       0            ['History', 'Nonfiction', 'Politics']     1.0
# 432   1901.0       0   ['Classics', 'Fiction', 'European Literature']     NaN
# 115   1985.0       0  ['Fiction', 'Historical', 'Historical Fiction']     NaN
#
#      minmax_norm_ratings  mean_norm_ratings  \
# 656                7.946              2.572
# 843                8.732              3.357
# 497                6.134              0.760
# 128                8.550              3.176
# 321                5.289             -0.086
# ..                   ...                ...
# 23                 7.161              1.787
# 611                4.443             -0.931
# 417                7.101              1.726
# 432                6.980              1.606
# 115                7.040              1.666
#
#                                                   Link
# 656  https://www.goodreads.com/book/show/10988.Drum...
# 843  https://www.goodreads.com/book/show/330244.The...
# 497  https://www.goodreads.com/book/show/228296.Ros...
# 128   https://www.goodreads.com/book/show/546018.Roots
# 321  https://www.goodreads.com/book/show/11566.The_...
# ..                                                 ...
# 23   https://www.goodreads.com/book/show/332613.One...
# 611  https://www.goodreads.com/book/show/113091.A_D...
# 417  https://www.goodreads.com/book/show/96123.All_...
# 432  https://www.goodreads.com/book/show/17343.Till...
# 115  https://www.goodreads.com/book/show/168668.Cat...
#
# [100 rows x 14 columns]

# %%
minmax_list = sample_df["minmax_norm_ratings"].tolist()
minmax_list.sort()
print(minmax_list)
# Out:
# [2.45, 2.752, 3.718, 3.96, 4.141, 4.383, 4.4430000000000005, 4.685, 4.805, 4.926, 4.987, 4.987, 5.167999999999998, 5.228, 5.289, 5.349, 5.409, 5.409, 5.47, 5.47, 5.53, 5.591, 5.651, 5.651, 5.651, 5.711, 5.711, 5.711, 5.832000000000002, 5.893, 5.9529999999999985, 5.9529999999999985, 5.9529999999999985, 6.013, 6.074, 6.074, 6.134, 6.134, 6.134, 6.195, 6.195, 6.195, 6.315, 6.315, 6.315, 6.376, 6.376, 6.376, 6.436, 6.436, 6.436, 6.436, 6.497000000000001, 6.497000000000001, 6.497000000000001, 6.497000000000001, 6.497000000000001, 6.557, 6.799, 6.859, 6.859, 6.859, 6.919, 6.919, 6.98, 6.98, 6.98, 6.98, 7.04, 7.04, 7.04, 7.101, 7.101, 7.101, 7.101, 7.101, 7.1610000000000005, 7.221, 7.221, 7.282, 7.282, 7.282, 7.342, 7.403, 7.462999999999999, 7.644, 7.705, 7.705, 7.705, 7.765, 7.886, 7.9460000000000015, 8.007, 8.309, 8.43, 8.55, 8.611, 8.671, 8.732000000000001, 8.972999999999997]

# %%
mean_norm = sample_df["mean_norm_ratings"].tolist()
mean_norm.sort()
print(mean_norm)
# Out:
# [-2.925, -2.623, -1.656, -1.415, -1.233, -0.992, -0.931, -0.69, -0.569, -0.448, -0.388, -0.388, -0.206, -0.146, -0.086, -0.025, 0.035, 0.035, 0.096, 0.096, 0.156, 0.21600000000000005, 0.277, 0.277, 0.277, 0.337, 0.337, 0.337, 0.458, 0.518, 0.579, 0.579, 0.579, 0.639, 0.7, 0.7, 0.76, 0.76, 0.76, 0.82, 0.82, 0.82, 0.941, 0.941, 0.941, 1.002, 1.002, 1.002, 1.062, 1.062, 1.062, 1.062, 1.122, 1.122, 1.122, 1.122, 1.122, 1.183, 1.4240000000000002, 1.485, 1.485, 1.485, 1.545, 1.545, 1.606, 1.606, 1.606, 1.606, 1.666, 1.666, 1.666, 1.726, 1.726, 1.726, 1.726, 1.726, 1.787, 1.847, 1.847, 1.908, 1.908, 1.908, 1.968, 2.028, 2.089, 2.27, 2.33, 2.33, 2.33, 2.391, 2.512, 2.572, 2.632, 2.934, 3.055, 3.176, 3.236, 3.297, 3.357, 3.599]

# %%
# Distribution plot of minmax normal distribution
sns.distplot(minmax_list, label='MinMax Norm', bins=20)
c=plt.legend()
plt.title("Min-Max Norm Distribution")
plt.savefig('minmax_norm.jpg')
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Distribution plot of mean normal distribution
sns.distplot(mean_norm, label='Mean Norm', color='red', bins=20)
c=plt.legend()
plt.title("Mean Norm Distribution")
plt.savefig('mean_norm.jpg')
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Distribution plot of both normal distributions
sns.distplot(minmax_list, label='MinMax Norm', color='blue')
sns.distplot(mean_norm, label='Mean Norm', color='red')
c=plt.legend()
plt.title("Comparison of Norm Distributions")
plt.savefig('norm_dists.jpg')
# Out:
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /shared-libs/python3.7/py/lib/python3.7/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
